# %%
run ETC_HARPS_NIRPS.py
# Out:
# --- 144.11772108078003 seconds ---

# %%
print(k_p)
print(RV_1)
print(RV_4)
print(phi_1)
print(phi_4)
# Out:
# 0.1812112401296286
# -0.05425541059826828
# 0.05425541059826828
# -0.04839395254400267
# 0.04839395254400267
