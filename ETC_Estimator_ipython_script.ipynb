# %% [markdown]
# # Running the ETC Estimator for NIRPS along with HARPS

# %% [markdown]
# #### Just run the line below to complete the simulation.

# %%
run ETC_HARPS_NIRPS.py
# Out:
# Calculate Planetary Blur? (Y/N): N
# Are the input parameters filled? (Y/N): Y
# Do you want to specify a custom path for storing the outputs? (y/n):
# -----------------------------------------------------------
# Outputs are stored in /Users/vigneshwarankrishnamurthy/Desktop/NIRPS/etc_calculators/outputs/WASP-121_4
#
# It took 22.254857063293457 seconds to compute this.

# %%
original_working_dir = os.getcwd()
print(original_working_dir)
# Out:
# /Users/vigneshwarankrishnamurthy/Desktop/NIRPS/etc_calculators
